# %% [markdown]
# <a href="https://colab.research.google.com/github/06-09-2004/Data-Science-Tutorials/blob/main/as_14_8_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#define a dictionary containing employee data
data1={'Name':['jai','princi','gaurav','anuj'],
       'Age':[27,24,22,32],
       'Address':['Nagpur','kanpur','allaahabad','kannuaj'],
       'qualification':['Msc','ma','mca','phd']}
#define a dictionary containing employee data
data2={'Name':['Abhi','ayushi','dhiraj','hitesh'],
       'age':[17,14,12,52],
       'Address':['Nagpur','kanpur','Allahabad','kannuaj'],
       'qualification':['btech','b.a','bcom','b.hons']}
#convert the dictionary into dataframe
df=pd.DataFrame(data1,index=[0,1,2,3])
#convert the dictionary into dataframe
df1=pd.DataFrame(data2,index=[4,5,6,7])
print(df,"\n\n",df1)
#using a .concat method
res1=pd.concat([df,df1])
res1
# Out:
#      Name  Age     Address qualification
# 0     jai   27      Nagpur           Msc
# 1  princi   24      kanpur            ma
# 2  gaurav   22  allaahabad           mca
# 3    anuj   32     kannuaj           phd
#
#       Name  age    Address qualification
# 4    Abhi   17     Nagpur         btech
# 5  ayushi   14     kanpur           b.a
# 6  dhiraj   12  Allahabad          bcom
# 7  hitesh   52    kannuaj        b.hons
#      Name   Age     Address qualification   age
# 0     jai  27.0      Nagpur           Msc   NaN
# 1  princi  24.0      kanpur            ma   NaN
# 2  gaurav  22.0  allaahabad           mca   NaN
# 3    anuj  32.0     kannuaj           phd   NaN
# 4    Abhi   NaN      Nagpur         btech  17.0
# 5  ayushi   NaN      kanpur           b.a  14.0
# 6  dhiraj   NaN   Allahabad          bcom  12.0
# 7  hitesh   NaN     kannuaj        b.hons  52.0

# %%
import pandas as pd
#define a dictionary containing employee data
data1={'Name':['jai','princi','gaurav','anuj'],
       'Age':[27,24,22,32],
       'Address':['Nagpur','kanpur','Allaahabad','kannuaj'],
       'qualification':['Msc','ma','mca','phd']}
#define a dictionary containing employee data
data2={'Name':['Abhi','ayushi','dhiraj','hitesh'],
       'age':[17,14,12,52],
       'Address':['Nagpur','kanpur','Allahabad','kannuaj'],
       'qualification':['btech','b.a','bcom','b.hons']}
#convert the dictionary into dataframe
df=pd.DataFrame(data1,index=[0,1,2,3])
#convert the dictionary into dataframe
df1=pd.DataFrame(data2,index=[2,3,6,7])
print(df,"\n\n",df1)
#using a .concat method
res1=pd.concat([df,df1])
res1
#applying concat with axes
#join="inner" we get the intersection of dataframe
res2=pd.concat([df,df1],axis=1,join='inner')
res2
# Out:
#      Name  Age     Address qualification
# 0     jai   27      Nagpur           Msc
# 1  princi   24      kanpur            ma
# 2  gaurav   22  Allaahabad           mca
# 3    anuj   32     kannuaj           phd
#
#       Name  age    Address qualification
# 2    Abhi   17     Nagpur         btech
# 3  ayushi   14     kanpur           b.a
# 6  dhiraj   12  Allahabad          bcom
# 7  hitesh   52    kannuaj        b.hons
#      Name  Age     Address qualification    Name  age Address qualification
# 2  gaurav   22  Allaahabad           mca    Abhi   17  Nagpur         btech
# 3    anuj   32     kannuaj           phd  ayushi   14  kanpur           b.a

# %%
#concatenating dataframes by ignoring indexes
import pandas as pd
#define a dictionary containing employee data
data1={'Name':['jai','princi','gaurav','anuj'],
       'Age':[27,24,22,32],
       'Address':['Nagpur','kanpur','Allaahabad','kannuaj'],
       'qualification':['Msc','ma','mca','phd']}
#define a dictionary containing employee data
data2={'Name':['Abhi','ayushi','dhiraj','hitesh'],
       'age':[17,14,12,52],
       'Address':['Nagpur','kanpur','Allahabad','kannuaj'],
       'qualification':['btech','b.a','bcom','b.hons']}
#convert the dictionary into dataframe
df=pd.DataFrame(data1,index=[0,1,2,3])
#convert the dictionary into dataframe
df1=pd.DataFrame(data2,index=[2,3,6,7])
print(df,"\n\n",df1)
#using a .concat method
res1=pd.concat([df,df1])
res1
#applying concat with axes
#join="inner" we get the intersection of dataframe
res2=pd.concat([df,df1],axis=1,join='inner')
res2
res=pd.concat([df,df1], ignore_index=True)
res
# Out:
#      Name  Age     Address qualification
# 0     jai   27      Nagpur           Msc
# 1  princi   24      kanpur            ma
# 2  gaurav   22  Allaahabad           mca
# 3    anuj   32     kannuaj           phd
#
#       Name  age    Address qualification
# 2    Abhi   17     Nagpur         btech
# 3  ayushi   14     kanpur           b.a
# 6  dhiraj   12  Allahabad          bcom
# 7  hitesh   52    kannuaj        b.hons
#      Name   Age     Address qualification   age
# 0     jai  27.0      Nagpur           Msc   NaN
# 1  princi  24.0      kanpur            ma   NaN
# 2  gaurav  22.0  Allaahabad           mca   NaN
# 3    anuj  32.0     kannuaj           phd   NaN
# 4    Abhi   NaN      Nagpur         btech  17.0
# 5  ayushi   NaN      kanpur           b.a  14.0
# 6  dhiraj   NaN   Allahabad          bcom  12.0
# 7  hitesh   NaN     kannuaj        b.hons  52.0

# %%
#concatenating a mix of series
#importing pandas module
import pandas as pd
#define a dictionary containing employee data
data1={'Name':['jai','princi','gaurav','anu'],
       'age':[27,24,22,32],
       'address':['nagpur','kanpur','allahabad','kannuaj'],
       'qualification':['msc','ma','mca','phd']}
#convert the dictionary  into dataframe
df=pd.DataFrame(data1,index=[0,1,2,3])
#creating a series
s1=pd.Series([1000,2000,3000,4000],name='salary')
print(df,"\n\n",s1)
#combining series and dataframe
res=pd.concat([df,s1],axis=1)
res
# Out:
#      Name  age    address qualification
# 0     jai   27     nagpur           msc
# 1  princi   24     kanpur            ma
# 2  gaurav   22  allahabad           mca
# 3     anu   32    kannuaj           phd
#
#  0    1000
# 1    2000
# 2    3000
# 3    4000
# Name: salary, dtype: int64
#      Name  age    address qualification  salary
# 0     jai   27     nagpur           msc    1000
# 1  princi   24     kanpur            ma    2000
# 2  gaurav   22  allahabad           mca    3000
# 3     anu   32    kannuaj           phd    4000

# %%
#Merging the dataframes using one key value
#importing pandas module
import pandas as pd
#define a dictionary containing employee data
data1={'key':['k0','k1','k2','k3'],
       'Name':['jai','princi','gaurav','anu'],
       'age':[27,24,22,32],}
#define a dictionary containing employee data
data2={'key':['k0','k1','k2','k3'],
       'Address':['Nagpur','Kanpur','Allahabad','kannuaj'],
       'Qualification':['btech','b.a','bcom','b.hons']}
#convert the dictionaty into dataframe
df=pd.DataFrame(data1)
#convert the dictionary into dataframe
df1=pd.DataFrame(data2)
print(df,"\n\n",df1)
#using .merge() function
res=pd.merge(df,df1,on='key')
res
# Out:
#   key    Name  age
# 0  k0     jai   27
# 1  k1  princi   24
# 2  k2  gaurav   22
# 3  k3     anu   32
#
#    key    Address Qualification
# 0  k0     Nagpur         btech
# 1  k1     Kanpur           b.a
# 2  k2  Allahabad          bcom
# 3  k3    kannuaj        b.hons
#   key    Name  age    Address Qualification
# 0  k0     jai   27     Nagpur         btech
# 1  k1  princi   24     Kanpur           b.a
# 2  k2  gaurav   22  Allahabad          bcom
# 3  k3     anu   32    kannuaj        b.hons

# %%
#merging dataframes using multiple key values
import pandas as pd
#define a dictionary containing employee data
data1={'key':['k0','k1','k2','k3'],
       'key1':['k0','k1','k0','k1'],
       'Address':['nagpur','kanpur','allahabad','kannuaj'],
       'Qualification':['btech','ms','msc','ba']}
#convert the dictionary into dataframe
df=pd.DataFrame(data1)
#convert the dictionary into dataframe
df1=pd.DataFrame(data2)
print(df,"\n\n",df1)
#merging dataframe using multiple keys
res1=pd.merge(df,df1,on=['key','key1'])
res1
# Out:
#   key key1    Address Qualification
# 0  k0   k0     nagpur         btech
# 1  k1   k1     kanpur            ms
# 2  k2   k0  allahabad           msc
# 3  k3   k1    kannuaj            ba
#
#    key    Address Qualification
# 0  k0     Nagpur         btech
# 1  k1     Kanpur           b.a
# 2  k2  Allahabad          bcom
# 3  k3    kannuaj        b.hons
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-da6c1df4031f> in <cell line: 14>()
#      12 print(df,"\n\n",df1)
#      13 #merging dataframe using multiple keys
# ---> 14 res1=pd.merge(df,df1,on=['key','key1'])
#      15 res1
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     167         )
#     168     else:
# --> 169         op = _MergeOperation(
#     170             left_df,
#     171             right_df,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     789             left_drop,
#     790             right_drop,
# --> 791         ) = self._get_merge_keys()
#     792
#     793         if left_drop:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1267                         rk = cast(Hashable, rk)
#    1268                         if rk is not None:
# -> 1269                             right_keys.append(right._get_label_or_level_values(rk))
#    1270                         else:
#    1271                             # work-around for merge_asof(right_index=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1842             values = self.axes[axis].get_level_values(key)._values
#    1843         else:
# -> 1844             raise KeyError(key)
#    1845
#    1846         # Check for duplicates
#
# KeyError: 'key1'
